# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

# %%
import os

# %%
import chromadb

# %%
chroma_client = chromadb.Client()

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_1 = pd.read_csv("/Users/Rakshit.Lodha/MF Search/mutual_fund_data.csv")

# %%
df_1['NAV'] = df_1['NAV'].apply(lambda x: round(np.random.uniform(10,300),2) if pd.isna(x) else x)

df_1['NAV'] = df_1['NAV'].round(2)

# %%
df_1
# Out:
#        Scheme_Code                                 Scheme_Name  \
# 0           100033  Aditya Birla Sun Life Large & Mid Cap Fund
# 1           100034  Aditya Birla Sun Life Large & Mid Cap Fund
# 2           100037           Aditya Birla Sun Life Income Fund
# 3           100038           Aditya Birla Sun Life Income Fund
# 4           100039           Aditya Birla Sun Life Income Fund
# ...            ...                                         ...
# 16192       154072           Edelweiss Silver ETF Fund of Fund
# 16193       154073           Edelweiss Silver ETF Fund of Fund
# 16194       154074           Edelweiss Silver ETF Fund of Fund
# 16195       154075           Edelweiss Silver ETF Fund of Fund
# 16196       154076                 JioBlackRock Arbitrage Fund
#
#                                                   AMC Scheme_Type  \
# 0                   Aditya Birla Sun Life AMC Limited  Open Ended
# 1                   Aditya Birla Sun Life AMC Limited  Open Ended
# 2                   Aditya Birla Sun Life AMC Limited  Open Ended
# 3                   Aditya Birla Sun Life AMC Limited  Open Ended
# 4                   Aditya Birla Sun Life AMC Limited  Open Ended
# ...                                               ...         ...
# 16192              Edelweiss Asset Management Limited  Open Ended
# 16193              Edelweiss Asset Management Limited  Open Ended
# 16194              Edelweiss Asset Management Limited  Open Ended
# 16195              Edelweiss Asset Management Limited  Open Ended
# 16196  Jio BlackRock Asset Management Private Limited  Open Ended
#
#                                   Scheme_Category  \
# 0            Equity Scheme - Large & Mid Cap Fund
# 1            Equity Scheme - Large & Mid Cap Fund
# 2      Debt Scheme - Medium to Long Duration Fund
# 3      Debt Scheme - Medium to Long Duration Fund
# 4      Debt Scheme - Medium to Long Duration Fund
# ...                                           ...
# 16192                 Other Scheme - FoF Domestic
# 16193                 Other Scheme - FoF Domestic
# 16194                 Other Scheme - FoF Domestic
# 16195                 Other Scheme - FoF Domestic
# 16196              Hybrid Scheme - Arbitrage Fund
#
#                                          Scheme_NAV_Name  \
# 0      Aditya Birla Sun Life Large & Mid Cap Fund - R...
# 1      Aditya Birla Sun Life Large & Mid Cap Fund -Re...
# 2      Aditya Birla Sun Life Income Fund - Regular - ...
# 3      Aditya Birla Sun Life Income Fund - Growth - R...
# 4               Birla Income Plus-Institutional (Growth)
# ...                                                  ...
# 16192                  Edelweiss Silver ETF Fund of Fund
# 16193  Edelweiss Silver ETF Fund of Fund - Direct Pla...
# 16194  Edelweiss Silver ETF Fund of Fund - Regular Pl...
# 16195  Edelweiss Silver ETF Fund of Fund - Regular Pl...
# 16196  JioBlackRock Arbitrage Fund - Direct Plan - Gr...
#
#                                           Scheme_Min_Amt     NAV  \
# 0                                                   5000  913.23
# 1                                                   5000  133.00
# 2                                                   5000   13.25
# 3                                                   5000  126.51
# 4                                                   5000   72.55
# ...                                                  ...     ...
# 16192  Minimum of Rs. 100 /- and in multiples of Re. 1/-   22.73
# 16193  Minimum of Rs. 100 /- and in multiples of Re. 1/-  204.10
# 16194  Minimum of Rs. 100 /- and in multiples of Re. 1/-  218.48
# 16195  Minimum of Rs. 100 /- and in multiples of Re. 1/-  132.10
# 16196               Rs. 500/- and any amount thereafter.   52.53
#
#       Latest_NAV_Date  Average_AUM_Cr           AAUM_Quarter  \
# 0            04/12/25       4513.2401  July - September 2025
# 1            04/12/25        499.3067  July - September 2025
# 2            04/12/25         11.7044  July - September 2025
# 3            04/12/25        836.9330  July - September 2025
# 4                 NaN             NaN                    NaN
# ...               ...             ...                    ...
# 16192             NaN             NaN                    NaN
# 16193             NaN             NaN                    NaN
# 16194             NaN             NaN                    NaN
# 16195             NaN             NaN                    NaN
# 16196             NaN             NaN                    NaN
#
#       ISIN_Div_Payout/Growth ISIN_Div_Reinvestment  \
# 0               INF209K01165                     -
# 1               INF209K01157          INF209K01CE5
# 2               INF209K01587          INF209K01CY3
# 3               INF209K01579                     -
# 4                        NaN                   NaN
# ...                      ...                   ...
# 16192                    NaN                   NaN
# 16193                    NaN                   NaN
# 16194                    NaN                   NaN
# 16195                    NaN                   NaN
# 16196                    NaN                   NaN
#
#       ISIN_Div_Payout/Growth/Div_Reinvestment Launch_Date Closure_Date
# 0                                INF209K01165    24/02/95     24/02/95
# 1                    INF209K01157INF209K01CE5    24/02/95     24/02/95
# 2                    INF209K01587INF209K01CY3    01/01/94     01/01/94
# 3                                INF209K01579    01/01/94     01/01/94
# 4                                         NaN    01/01/94     01/01/94
# ...                                       ...         ...          ...
# 16192                                     NaN    08/12/25          NaN
# 16193                                     NaN    08/12/25          NaN
# 16194                                     NaN    08/12/25          NaN
# 16195                                     NaN    08/12/25          NaN
# 16196                            INF22M001101    09/12/25          NaN
#
# [16197 rows x 16 columns]

# %%
df_1['Average_AUM_Cr'] = df_1['Average_AUM_Cr'].apply(lambda x: round(np.random.uniform(100,9000),2) if pd.isna(x) else x)

df_1['Average_AUM_Cr'] = df_1['Average_AUM_Cr'].round(2)

# %%
df_1['1_Yr_Returns'] = np.random.uniform(-10,30,df_1.shape[0]).round(2)
df_1['5_Yr_Returns'] = np.random.uniform(-10,30,df_1.shape[0]).round(2)
df_1['3_Yr_Returns'] = np.random.uniform(-10,30,df_1.shape[0]).round(2)
df_1['Expense_Ratio'] = np.random.uniform(0.05,2,df_1.shape[0]).round(2)
df_1['Benchmark_Return'] = np.random.uniform(-10,20,df_1.shape[0]).round(2)

# %%
df_1
# Out:
#        Scheme_Code                                 Scheme_Name  \
# 0           100033  Aditya Birla Sun Life Large & Mid Cap Fund
# 1           100034  Aditya Birla Sun Life Large & Mid Cap Fund
# 2           100037           Aditya Birla Sun Life Income Fund
# 3           100038           Aditya Birla Sun Life Income Fund
# 4           100039           Aditya Birla Sun Life Income Fund
# ...            ...                                         ...
# 16192       154072           Edelweiss Silver ETF Fund of Fund
# 16193       154073           Edelweiss Silver ETF Fund of Fund
# 16194       154074           Edelweiss Silver ETF Fund of Fund
# 16195       154075           Edelweiss Silver ETF Fund of Fund
# 16196       154076                 JioBlackRock Arbitrage Fund
#
#                                                   AMC Scheme_Type  \
# 0                   Aditya Birla Sun Life AMC Limited  Open Ended
# 1                   Aditya Birla Sun Life AMC Limited  Open Ended
# 2                   Aditya Birla Sun Life AMC Limited  Open Ended
# 3                   Aditya Birla Sun Life AMC Limited  Open Ended
# 4                   Aditya Birla Sun Life AMC Limited  Open Ended
# ...                                               ...         ...
# 16192              Edelweiss Asset Management Limited  Open Ended
# 16193              Edelweiss Asset Management Limited  Open Ended
# 16194              Edelweiss Asset Management Limited  Open Ended
# 16195              Edelweiss Asset Management Limited  Open Ended
# 16196  Jio BlackRock Asset Management Private Limited  Open Ended
#
#                                   Scheme_Category  \
# 0            Equity Scheme - Large & Mid Cap Fund
# 1            Equity Scheme - Large & Mid Cap Fund
# 2      Debt Scheme - Medium to Long Duration Fund
# 3      Debt Scheme - Medium to Long Duration Fund
# 4      Debt Scheme - Medium to Long Duration Fund
# ...                                           ...
# 16192                 Other Scheme - FoF Domestic
# 16193                 Other Scheme - FoF Domestic
# 16194                 Other Scheme - FoF Domestic
# 16195                 Other Scheme - FoF Domestic
# 16196              Hybrid Scheme - Arbitrage Fund
#
#                                          Scheme_NAV_Name  \
# 0      Aditya Birla Sun Life Large & Mid Cap Fund - R...
# 1      Aditya Birla Sun Life Large & Mid Cap Fund -Re...
# 2      Aditya Birla Sun Life Income Fund - Regular - ...
# 3      Aditya Birla Sun Life Income Fund - Growth - R...
# 4               Birla Income Plus-Institutional (Growth)
# ...                                                  ...
# 16192                  Edelweiss Silver ETF Fund of Fund
# 16193  Edelweiss Silver ETF Fund of Fund - Direct Pla...
# 16194  Edelweiss Silver ETF Fund of Fund - Regular Pl...
# 16195  Edelweiss Silver ETF Fund of Fund - Regular Pl...
# 16196  JioBlackRock Arbitrage Fund - Direct Plan - Gr...
#
#                                           Scheme_Min_Amt     NAV  \
# 0                                                   5000  913.23
# 1                                                   5000  133.00
# 2                                                   5000   13.25
# 3                                                   5000  126.51
# 4                                                   5000   72.55
# ...                                                  ...     ...
# 16192  Minimum of Rs. 100 /- and in multiples of Re. 1/-   22.73
# 16193  Minimum of Rs. 100 /- and in multiples of Re. 1/-  204.10
# 16194  Minimum of Rs. 100 /- and in multiples of Re. 1/-  218.48
# 16195  Minimum of Rs. 100 /- and in multiples of Re. 1/-  132.10
# 16196               Rs. 500/- and any amount thereafter.   52.53
#
#       Latest_NAV_Date  Average_AUM_Cr  ... ISIN_Div_Payout/Growth  \
# 0            04/12/25         4513.24  ...           INF209K01165
# 1            04/12/25          499.31  ...           INF209K01157
# 2            04/12/25           11.70  ...           INF209K01587
# 3            04/12/25          836.93  ...           INF209K01579
# 4                 NaN         7886.91  ...                    NaN
# ...               ...             ...  ...                    ...
# 16192             NaN         2602.68  ...                    NaN
# 16193             NaN         2757.10  ...                    NaN
# 16194             NaN         7943.33  ...                    NaN
# 16195             NaN         1884.97  ...                    NaN
# 16196             NaN          247.89  ...                    NaN
#
#       ISIN_Div_Reinvestment ISIN_Div_Payout/Growth/Div_Reinvestment  \
# 0                         -                            INF209K01165
# 1              INF209K01CE5                INF209K01157INF209K01CE5
# 2              INF209K01CY3                INF209K01587INF209K01CY3
# 3                         -                            INF209K01579
# 4                       NaN                                     NaN
# ...                     ...                                     ...
# 16192                   NaN                                     NaN
# 16193                   NaN                                     NaN
# 16194                   NaN                                     NaN
# 16195                   NaN                                     NaN
# 16196                   NaN                            INF22M001101
#
#       Launch_Date Closure_Date 1_Yr_Returns  5_Yr_Returns  3_Yr_Returns  \
# 0        24/02/95     24/02/95        -6.20          3.49         13.74
# 1        24/02/95     24/02/95        26.81         22.15         27.53
# 2        01/01/94     01/01/94        26.39          2.41         18.64
# 3        01/01/94     01/01/94         9.06         27.56         -1.92
# 4        01/01/94     01/01/94        15.04         28.15          8.29
# ...           ...          ...          ...           ...           ...
# 16192    08/12/25          NaN        11.06         15.97         29.22
# 16193    08/12/25          NaN        23.41         16.48         19.45
# 16194    08/12/25          NaN        -4.87         24.38         -8.15
# 16195    08/12/25          NaN        27.09         -2.57         -6.82
# 16196    09/12/25          NaN        15.24         11.89          0.48
#
#        Expense_Ratio  Benchmark_Return
# 0               0.95             -5.69
# 1               0.62             11.14
# 2               0.36             -1.47
# 3               0.98             10.13
# 4               0.38             -9.31
# ...              ...               ...
# 16192           1.53             -2.78
# 16193           0.55              5.50
# 16194           1.85              8.63
# 16195           0.14             -7.82
# 16196           0.61              3.14
#
# [16197 rows x 21 columns]
